# %%
import pandas as pd


df = pd.read_html('https://en.wikipedia.org/wiki/Premier_League')[1]
df
# Out:
#                                               Season  \
# 0                                            1992–93
# 1                                            1993–94
# 2                                            1994–95
# 3                                            1995–96
# 4                                            1996–97
# 5                                            1997–98
# 6                                            1998–99
# 7                                          1999–2000
# 8  .mw-parser-output .legend{page-break-inside:av...
#
#                                            Champions  \
# 0                                  Manchester United
# 1                                  Manchester United
# 2                                   Blackburn Rovers
# 3                                  Manchester United
# 4                                  Manchester United
# 5                                            Arsenal
# 6                                  Manchester United
# ...
